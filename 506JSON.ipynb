# %%
#Open a text file in 'Write'mode to write the given lines
f=open("textfile.txt",'w')
f.write("first line\n")
f.write("second line\n")
f.write("thrid line\n")
f.close()
#Open a text file in'Read'mode to read and print the available lines-readline function
k=open("textfile.txt",'r')
print(k.readline())
print(k.readline())
print(k.readline())
k.close()
# Out:
# first line
#
# second line
#
# thrid line

# %%
#open a text file in'Append'mode to add/append new line inputs
m=open("textfile.txt",'a')
m.write("fourth line\n")
m.write("fifth line\n")
m.close()

#Open a text file in'Read'mode to read and print the available full text-read function
p=open("textfile.txt",'r')
print(p.read())
p.close()
# Out:
# fourth line
# fifth line

# %%
with open("textfile.txt",'r')as file:
  lines=file.readlines()
print(lines)
# Out:
# ['first line\n', 'second line\n', 'thrid line\n']

# %%
import json

# JSON string (fixed: properly closed the string literal and JSON object)
x = '{"name":"john","age":30,"city":"New York"}'

# Convert JSON string to python dictionary
y = json.loads(x)
print(y["age"])
# Out:
# 30

# %%
#Python dictionary
data={
    "name":"john",
    "age":30,
    "city":"New york"
}
json_data=json.dumps(data)
print(json_data)
# Out:
# {"name": "john", "age": 30, "city": "New york"}
