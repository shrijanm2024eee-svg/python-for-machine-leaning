# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.839542 -0.234995  0.099431
# b       NaN       NaN       NaN
# c  0.758314 -0.402853  0.240691
# d -0.463994  2.837053 -0.396029
# e       NaN       NaN       NaN
# f -1.397781 -1.188702  0.546796
#
#
# Dropped DataFrame
#          one       two     three
# a -0.839542 -0.234995  0.099431
# c  0.758314 -0.402853  0.240691
# d -0.463994  2.837053 -0.396029
# f -1.397781 -1.188702  0.546796

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.439351 -1.251579  0.160618
# b       NaN       NaN       NaN
# c -0.136523 -1.270251  1.277740
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.439351 -1.251579  0.160618
# b  0.000000  0.000000  0.000000
# c -0.136523 -1.270251  1.277740

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  0.173814 -0.484794  1.175815
# b       NaN       NaN       NaN
# c -1.049340  2.167330  0.133094
# d -2.436944  0.530742  0.482716
# e       NaN       NaN       NaN
# f -0.410631  1.028593  1.251481
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.463958  0.061278  0.378673
# b       NaN       NaN       NaN
# c  0.622300 -1.429393 -0.491990
# d -0.207292  0.657276 -0.325351
# e       NaN       NaN       NaN
# f  0.937903  0.109686 -0.096067
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -0.463958  0.061278  0.378673
# b  0.622300 -1.429393 -0.491990
# c  0.622300 -1.429393 -0.491990
# d -0.207292  0.657276 -0.325351
# e  0.937903  0.109686 -0.096067
# f  0.937903  0.109686 -0.096067
# /tmp/ipykernel_180/4216389697.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
