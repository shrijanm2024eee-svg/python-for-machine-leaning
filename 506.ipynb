# %%
import pandas as pd
d = pd.read_csv(r"C:\Users\Tcs\Downloads\em.csv")
print(d)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1682074824.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 d = pd.read_csv(r"C:\Users\Tcs\Downloads\em.csv")
#       3 print(d)
#
# ...

# %%
import pandas as pd
d = pd.read_csv("em.csv")
print(d)
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
print("Emp ID", df['Emp ID'])
# Out:
# Emp ID 0     677509
# 1     940761
# 2     428945
# 3     408351
# 4     193819
#        ...
# 95    639892
# 96    704709
# 97    461593
# 98    392491
# 99    495141
# Name: Emp ID, Length: 100, dtype: int64

# %%
#Get the column heading
df=pd.DataFrame(d)
print("columns",df.columns)
# Out:
# columns Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Salary'],
#       dtype='object')

# %%
#Extract/slice the table values-[including this row,excluding this row]
print(df[5:9])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
# 8  477616        Hon.    Frances              B     Young      F
#
#                     E Mail  Father's Name     Mother's Name  \
# 5   patrick.bailey@aol.com   Ralph Bailey      Laura Bailey
# 6       nancy.baker@bp.com    Scott Baker        Judy Baker
# 7   carol.murphy@gmail.com  Eugene Murphy  Katherine Murphy
# 8  frances.young@gmail.com     Fred Young     Lillian Young
#
#   Mother's Maiden Name  Salary
# 5            Henderson   72305
# 6               Thomas   98189
# 7             Peterson   60918
# 8                 Diaz  121587

# %%
#Get the particular row values-throught row number identification
print("particular person details",df.loc[12])
# Out:
# particular person details Emp ID                                    386158
# Name Prefix                                 Mrs.
# First Name                               Melissa
# Middle Initial                                 Q
# Last Name                                   King
# Gender                                         F
# E Mail                  melissa.king@comcast.net
# Father's Name                        Philip King
# Mother's Name                         Maria King
# Mother's Maiden Name                       White
# Salary                                    166892
# Name: 12, dtype: object

# %%
#Get the particular row values-throught'Salary'identification
print(d.loc[d['Salary']==117642])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 4  193819         Mr.   Benjamin              R   Russell      M
#
#                          E Mail    Father's Name      Mother's Name  \
# 4  benjamin.russell@charter.net  Gregory Russell  Elizabeth Russell
#
#   Mother's Maiden Name  Salary
# 4               Nelson  117642

# %%
df=d['Salary']/5
print("\nMake an average of total salary:\n",df)
# Out:
# Make an average of total salary:
#  0     33650.2
# 1     10212.6
# 2     10031.0
# 3     36058.8
# 4     23528.4
#        ...
# 95    25954.8
# 96    31238.8
# 97    19134.6
# 98    10203.0
# 99    18730.0
# Name: Salary, Length: 100, dtype: float64
